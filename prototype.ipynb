# %%
import os
import shutil
from PIL import Image, ExifTags #pip install Pillow pillow-heif
from datetime import datetime
from pathlib import Path

# %%
import subprocess

# %%
try:
    from pillow_heif import register_heif_opener
    register_heif_opener()  # Enables reading HEIC/HEIF (iPhone photos)
except ImportError:
    print("Install pillow-heif for HEIC support: pip install pillow-heif")

# %%
def get_exif_date(image_path):
    """Try multiple EXIF date tags for images (fallback if DateTimeOriginal is missing)."""
    try:
        image = Image.open(image_path)
        exif_data = image._getexif()
        if exif_data:
            date_tags = ["DateTimeOriginal", "DateTimeDigitized", "DateTime"]
            for tag, value in exif_data.items():
                tag_name = ExifTags.TAGS.get(tag)
                if tag_name in date_tags:
                    try:
                        return datetime.strptime(value, "%Y:%m:%d %H:%M:%S")
                    except Exception:
                        continue
    except Exception:
        pass
    return None

# %%
def get_video_date(video_path):
    """Extract 'Date Taken' from video metadata using ffprobe (if available)."""
    try:
        result = subprocess.run(
            ["ffprobe", "-v", "error", "-show_entries",
             "format_tags=creation_time", "-of",
             "default=noprint_wrappers=1:nokey=1", video_path],
            stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True
        )
        date_str = result.stdout.strip()
        if date_str:
            try:
                return datetime.fromisoformat(date_str.replace("Z", "+00:00"))
            except ValueError:
                pass
    except FileNotFoundError:
        print("Install ffmpeg/ffprobe for video metadata support.")
    return None

# %%
def get_file_system_date(file_path):
    """Fallback to file creation/modification date if no EXIF/metadata available."""
    try:
        ts = os.path.getmtime(file_path)  # modification time (works cross-platform)
        return datetime.fromtimestamp(ts)
    except Exception:
        return None

# %%
def get_date_taken(file_path):
    """Get date taken from EXIF, video metadata, or fallback to file system date."""
    ext = file_path.lower()
    date_taken = None

    if ext.endswith((".jpg", ".jpeg", ".png", ".heic", ".heif")):
        date_taken = get_exif_date(file_path)
    elif ext.endswith((".mp4", ".mov", ".avi", ".mkv")):
        date_taken = get_video_date(file_path)

    if not date_taken:
        date_taken = get_file_system_date(file_path)

    return date_taken

# %%
def get_unique_filename(folder, filename):
    """Generate a unique filename if duplicate exists."""
    base, ext = os.path.splitext(filename)
    counter = 1
    new_filename = filename
    while os.path.exists(os.path.join(folder, new_filename)):
        new_filename = f"{base}({counter}){ext}"
        counter += 1
    return new_filename

# %%
def format_filename_by_date(date_taken, ext):
    """Format filename based on date and time."""
    return f"{date_taken.strftime('%Y-%m-%d_%H-%M-%S')}{ext.lower()}"

# %%
def sort_media_by_date(source_folder, destination_folder, rename_by_date=False):
    """Sort images & videos into folders by year and month based on metadata."""
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    unsorted_folder = os.path.join(destination_folder, "Unsorted")
    os.makedirs(unsorted_folder, exist_ok=True)

    for root, _, files in os.walk(source_folder):
        for file in files:
            file_path = os.path.join(root, file)

            if not file.lower().endswith((".jpg", ".jpeg", ".png", ".heic", ".heif", ".mp4", ".mov", ".avi", ".mkv")):
                continue

            date_taken = get_date_taken(file_path)
            if date_taken:
                folder_name = f"{date_taken.year}-{date_taken.month:02d}"
                target_folder = os.path.join(destination_folder, folder_name)
                new_filename = (
                    format_filename_by_date(date_taken, Path(file).suffix)
                    if rename_by_date else file
                )
            else:
                target_folder = unsorted_folder
                new_filename = file

            os.makedirs(target_folder, exist_ok=True)
            unique_name = get_unique_filename(target_folder, new_filename)
            shutil.copy2(file_path, os.path.join(target_folder, unique_name))
            print(f"Copied: {file} → {target_folder}/{unique_name}")

# %%
source = '/Users/max/Pictures/Temp/iphone_photos_unsorted'

# %%
destination = '/Users/max/Pictures/Temp/iphone_photos_sorted'

# %%
rename_option = 'y'

# %%
sort_media_by_date(source, destination, rename_by_date=rename_option)
# Out:
# Copied: IMG_E2663.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_06-34-55.jpg
# Copied: IMG_2603.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_12-02-17.jpg
# Copied: IMG_2641.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_16-45-20(2).mov
# Copied: IMG_2494.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-24(1).mov
# Copied: IMG_3723.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-30_22-19-22.jpg
# Copied: IMG_E2529.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-02.jpg
# Copied: IMG_2575.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-17.jpg
# Copied: IMG_2561.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-54.jpg
# Copied: IMG_2549.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-37.jpg
# Copied: IMG_2537.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-34-51(2).mov
# Copied: IMG_2788.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-12_15-17-10.jpg
# Copied: IMG_9890.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-19-15(6).mov
# Copied: IMG_9885.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-18-59(5).mov
# Copied: IMG_9891.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-19-15(7).mov
# Copied: IMG_2536.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-34-51(3).mov
# Copied: IMG_2548.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-36.jpg
# Copied: IMG_2560.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-53.jpg
# Copied: IMG_2574.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-15.jpg
# Copied: IMG_E2528.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-01.jpg
# Copied: IMG_2495.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-25(1).mov
# Copied: IMG_2640.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_16-45-20(3).mov
# Copied: IMG_2602.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-57-14.jpg
# Copied: NNRZ1363.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-19_20-43-03(2).jpg
# Copied: IMG_2681.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_18-33-25(1).mov
# Copied: IMG_2600.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-49-29.jpg
# Copied: IMG_2614.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_20-51-09(1).png
# Copied: IMG_2497.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-27(7).mov
# Copied: IMG_2589.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-37.jpg
# Copied: IMG_2562.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-55.jpg
# Copied: IMG_2508.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-33(6).mov
# Copied: IMG_2576.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-17(1).jpg
# Copied: IMG_2534.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-34-34(1).mov
# Copied: IMG_2520.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-33(8).mov
# Copied: IMG_9878.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-27-53(1).mov
# Copied: IMG_9887.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-18-59(6).mov
# Copied: IMG_9893.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-19-15(8).mov
# Copied: IMG_9892.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-19-15(9).mov
# Copied: IMG_9886.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-18-59(7).mov
# Copied: IMG_9879.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-28-01(1).mov
# Copied: IMG_2521.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2024-01/2024-01-14_10-32-20.mov
# Copied: IMG_2535.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-34-39(1).mov
# Copied: IMG_2577.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-23.jpg
# Copied: IMG_2563.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-57.jpg
# Copied: IMG_2509.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-33(7).mov
# Copied: IMG_2588.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-36.jpg
# Copied: IMG_2496.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-26(1).mov
# Copied: IMG_2615.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_20-51-36(1).png
# Copied: IMG_2643.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2024-01/2024-01-14_10-30-49.mov
# Copied: IMG_2601.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-56-10.jpg
# Copied: IMG_E2659.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-26_17-30-06.jpg
# Copied: IMG_2611.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_15-35-26.jpg
# Copied: IMG_2492.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_09-12-57(1).mov
# Copied: _DSC3686.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-49-22(1).jpg
# Copied: IMG_3719.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-29_13-30-22.jpg
# Copied: IMG_2567.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-03.jpg
# Copied: IMG_2573.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-13.jpg
# Copied: IMG_2519.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-33(9).mov
# Copied: IMG_9869.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-12(5).mov
# Copied: IMG_9882.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_09-02-14(1).mov
# Copied: IMG_9896.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-44-06(1).mov
# Copied: IMG_9868.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-12(6).mov
# Copied: IMG_2572.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-13(1).jpg
# Copied: IMG_2518.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-33(10).mov
# Copied: IMG_2566.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-02.jpg
# Copied: IMG_2599.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-49-24.jpg
# Copied: IMG_2478.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-26-07(1).mov
# Copied: IMG_2638.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_17-26-14(1).png
# Copied: IMG_2610.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_15-33-22.jpg
# Copied: IMG_2652.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-24_08-07-08(1).mov
# Copied: IMG_2650.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-23_11-16-56(1).mov
# Copied: IMG_2678.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_17-29-57(1).mov
# Copied: IMG_2612.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_15-48-06.jpg
# Copied: IMG_2491.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_09-04-05(1).mov
# Copied: IMG_2558.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-50.jpg
# Copied: IMG_2570.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-08.jpg
# Copied: IMG_2564.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-59.jpg
# Copied: MNWS7999 1.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_22-16-29.jpg
# Copied: IMG_3322.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-06_19-34-21.jpg
# Copied: IMG_9895.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-19-15(10).mov
# Copied: IMG_9881.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-28-06(1).mov
# Copied: IMG_9880.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-28-04(1).mov
# Copied: IMG_9894.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-19-15(11).mov
# Copied: IMG_3323.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-06_19-34-24.jpg
# Copied: IMG_2565.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-00.jpg
# Copied: IMG_2571.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-10.jpg
# Copied: IMG_2559.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-51.jpg
# Copied: IMG_2613.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_17-46-17.png
# Copied: IMG_2490.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_08-34-57(1).mov
# Copied: IMG_2607.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_14-58-53.jpg
# Copied: IMG_2651.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-23_11-22-47(1).mov
# Copied: IMG_E2667.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_18-24-00.jpg
# Copied: LRCJ3718.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-24_22-41-18.png
# Copied: IMG_2660.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_06-34-22.jpg
# Copied: IMG_2489.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_11-29-01(1).png
# Copied: IMG_2636.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_13-39-06(1).mov
# Copied: IMG_2648.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-22_22-08-23.png
# Copied: IMG_2700.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-01_09-35-27(1).png
# Copied: IMG_E2562.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-55(1).jpg
# Copied: IMG_2583.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-27(7).mov
# Copied: IMG_2597.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-36-02(2).mov
# Copied: _DSC3783.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-47-30(1).jpg
# Copied: IMG_2516.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-31.jpg
# Copied: IMG_2502.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-25.jpg
# Copied: RIDA1107.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_22-21-00.jpg
# Copied: IMG_2540.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-35-19(1).mov
# Copied: IMG_E2589.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-37(1).jpg
# Copied: IMG_9866.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-08.jpg
# Copied: IMG_9872.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-11.jpg
# Copied: IMG_9873.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-27-40.jpg
# Copied: IMG_9867.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-09.jpg
# Copied: IMG_2541.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-35-21(1).mov
# Copied: IMG_E2588.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-36(1).jpg
# Copied: IMG_2503.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-25(1).jpg
# Copied: IMG_2517.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-32.jpg
# Copied: IMG_2596.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-36-02(3).mov
# Copied: IMG_2582.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-27(8).mov
# Copied: IMG_E2563.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-57(1).jpg
# Copied: IMG_2701.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-01_09-36-00(1).png
# Copied: IMG_2488.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_11-28-51(1).png
# Copied: IMG_3225.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-11/2022-11-23_20-25-18.jpg
# Copied: IMG_2661.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_06-34-52.jpg
# Copied: IMG_2477.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_18-32-44(1).png
# Copied: IMG_2609.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_12-30-04(1).mov
# Copied: IMG_2663.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_06-34-55(1).jpg
# Copied: IMG_2635.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_13-39-04(1).mov
# Copied: IMG_2688.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-29_10-34-12(1).png
# Copied: IMG_E2561.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-54(1).jpg
# Copied: IMG_2703.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-02_10-30-56(1).png
# Copied: IMG_2594.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-28-01(2).mov
# Copied: IMG_E2549.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-37(1).jpg
# Copied: IMG_2580.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-27(9).mov
# Copied: IMG_2501.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-24.jpg
# Copied: IMG_2515.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-30.jpg
# Copied: IMG_2273.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-11_23-18-58.jpg
# Copied: IMG_2529.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-02(1).jpg
# Copied: IMG_9859.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_10-59-57.jpg
# Copied: IMG_9871.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-11(1).jpg
# Copied: KXJH8257.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_21-41-22.jpg
# Copied: IMG_9865.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-07.jpg
# Copied: IMG_9864.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-06.jpg
# Copied: IMG_9870.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-10.jpg
# Copied: VAHP8894.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-45-37(2).jpg
# Copied: IMG_2528.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-01(1).jpg
# Copied: IMG_2542.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2024-01/2024-01-14_10-31-55.mov
# Copied: IMG_2514.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-30(1).jpg
# Copied: IMG_2500.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-24(1).jpg
# Copied: IMG_E2548.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-36(1).jpg
# Copied: IMG_2581.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-27(10).mov
# Copied: IMG_2595.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-28-01(3).mov
# Copied: IMG_E2560.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-53(1).jpg
# Copied: IMG_2608.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_12-28-23(1).mov
# Copied: IMG_2662.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_06-34-55(2).jpg
# Copied: IMG_2666.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_15-48-27.jpg
# Copied: IMG_2699.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-01_09-35-16(1).png
# Copied: IMG_E2558.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-50(1).jpg
# Copied: IMG_2591.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-27-14(2).mov
# Copied: IMG_E2564.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-59(1).jpg
# Copied: IMG_E2570.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-08(1).jpg
# Copied: IMG_2706.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2024-01/2024-01-14_12-55-28.png
# Copied: IMG_2538.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-35-03.jpg
# Copied: IMG_2504.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-28.jpg
# Copied: IMG_2510.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-32.jpg
# Copied: IMG_9874.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-27-42.jpg
# Copied: IMG_9860.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-04.jpg
# Copied: IMG_9861.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-04(1).jpg
# Copied: IMG_9875.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-27-44.jpg
# Copied: IMG_2511.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-26.jpg
# Copied: IMG_2505.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-29.jpg
# Copied: IMG_2539.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-35-04.jpg
# Copied: IMG_E2571.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-10(1).jpg
# Copied: IMG_E2565.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-00(1).jpg
# Copied: IMG_E2559.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-51(1).jpg
# Copied: IMG_2590.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-27-14(3).mov
# Copied: IMG_2698.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-01_09-35-00(1).png
# Copied: IMG_2667.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_18-24-00(1).jpg
# Copied: IMG_3590.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-20_14-23-23.jpg
# Copied: IMG_2498.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-23.jpg
# Copied: IMG_2659.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-26_17-30-06.png
# Copied: _DSC3631.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-50-22.jpg
# Copied: IMG_2665.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_15-21-10.png
# Copied: IMG_2592.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-27-17(1).mov
# Copied: IMG_2705.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2024-01/2024-01-14_12-55-04.png
# Copied: IMG_E2567.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-03(1).jpg
# Copied: IMG_2513.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-29.jpg
# Copied: IMG_2579.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-27(11).mov
# Copied: IMG_2507.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-31.jpg
# Copied: IMG_9863.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-05.jpg
# Copied: IMG_9877.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-27-50.jpg
# Copied: IMG_9888.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-18-57.jpg
# Copied: IMG_9889.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-18-57(1).jpg
# Copied: IMG_9876.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-27-49.jpg
# Copied: IMG_9862.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-05(1).jpg
# Copied: IMG_2506.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-30.jpg
# Copied: IMG_2512.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-28.jpg
# Copied: KXXE5053.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_22-16-16.jpg
# Copied: IMG_2274.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-11_23-20-41.jpg
# Copied: IMG_2578.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-27(12).mov
# Copied: IMG_E2566.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-02(1).jpg
# Copied: IMG_2593.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-27-20(1).mov
# Copied: _DSC3778.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-48-17(2).jpg
# Copied: IMG_3036.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-25_14-19-32.jpg
# Copied: IMG_2658.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-26_17-10-49.png
# Copied: IMG_2499.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-24(2).jpg
# Copied: IMG_2664.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_11-18-24.jpg
# Copied: IMG_3591.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-20_14-27-02.jpg
# Copied: IMG_E2638.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_17-26-14.jpg
# Copied: IMG_3588.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-20_14-22-40.jpg
# Copied: IMG_E2663.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2024-01/2024-01-14_10-30-45.mov
# Copied: IMG_2641.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_19-45-19.jpg
# Copied: IMG_2480.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_09-21-05(1).png
# Copied: IMG_2603.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_09-02-17(1).mov
# Copied: IMG_2494.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-21.jpg
# Copied: IMG_E2557.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-49.jpg
# Copied: IMG_E2543.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-06.jpg
# Copied: IMG_2537.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-50.jpg
# Copied: IMG_2523.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-33-30.jpg
# Copied: IMG_2575.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-18(3).mov
# Copied: IMG_9890.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-19-12.jpg
# Copied: IMG_9891.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-19-12(1).jpg
# Copied: IMG_9885.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-18-54.jpg
# Copied: IMG_2522.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_21-59-52(1).png
# Copied: IMG_2574.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-18(4).mov
# Copied: IMG_2278.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-21_09-50-42.jpg
# Copied: IMG_2536.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-49.jpg
# Copied: IMG_3827.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2023-01/2023-01-12_20-57-16.jpg
# Copied: IMG_E2556.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-48.jpg
# Copied: IMG_2697.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-01_09-34-48(1).png
# Copied: IMG_2495.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-21(1).jpg
# Copied: IMG_2602.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-57-14(1).mov
# Copied: IMG_2481.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_09-21-21(1).png
# Copied: IMG_2640.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_19-45-18.jpg
# Copied: VODN8249.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-48-17(3).jpg
# Copied: IMG_3589.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-20_14-22-53.jpg
# Copied: IMG_2681.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_21-33-25.jpg
# Copied: IMG_2483.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_09-22-33(1).png
# Copied: IMG_2600.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-49-29(1).mov
# Copied: IMG_2497.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-23(1).jpg
# Copied: IMG_2656.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-26_17-02-55.png
# Copied: MNWS7999.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_22-16-29(1).jpg
# Copied: IMG_E2554.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-44.jpg
# Copied: IMG_E2568.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-05.jpg
# Copied: IMG_2520.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-33.jpg
# Copied: IMG_2534.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-34.jpg
# Copied: IMG_2576.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-18(5).mov
# Copied: IMG_2508.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-31(1).jpg
# Copied: IMG_9878.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-27-53.jpg
# Copied: IMG_9893.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-19-13.jpg
# Copied: IMG_9887.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-18-56.jpg
# Copied: IMG_9886.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-18-55.jpg
# Copied: IMG_9892.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-19-13(1).jpg
# Copied: IMG_9879.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-28-01.jpg
# Copied: IMG_2509.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-31(2).jpg
# Copied: IMG_2577.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-27(13).mov
# Copied: IMG_2535.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-39.jpg
# Copied: IMG_E2569.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-06.jpg
# Copied: IMG_E2555.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-45.jpg
# Copied: _DSC3830.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-45-37(3).jpg
# Copied: IMG_2309 1.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2023-01/2023-01-25_15-25-49.jpg
# Copied: IMG_2657.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-26_17-03-03.png
# Copied: IMG_2496.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-15-22.jpg
# Copied: IMG_2601.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-56-10(1).mov
# Copied: IMG_2482.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_09-21-48(1).png
# Copied: IMG_2479.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_09-20-52(1).png
# Copied: IMG_2611.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_12-35-26(1).mov
# Copied: IMG_2492.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_12-12-59.jpg
# Copied: IMG_2647.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-22_22-08-14.png
# Copied: IMG_2690.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-29_14-43-42.png
# Copied: IMG_E2545.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-32.jpg
# Copied: IMG_E2551.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-39.jpg
# Copied: IMG_2519.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-32(1).jpg
# Copied: IMG_2573.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-15(2).mov
# Copied: IMG_2525.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-33-38.jpg
# Copied: IMG_E2586.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-33.jpg
# Copied: IMG_2531.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-16.jpg
# Copied: IMG_9869.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-10(1).jpg
# Copied: IMG_9896.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-44-07.jpg
# Copied: IMG_9882.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-02-18.jpg
# Copied: IMG_9868.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-00-10(2).jpg
# Copied: IMG_2530.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-13.jpg
# Copied: IMG_E2587.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-34.jpg
# Copied: IMG_2524.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-33-37.jpg
# Copied: IMG_2518.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_16-28-32(2).jpg
# Copied: IMG_2572.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-38-15(3).mov
# Copied: IMG_2599.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_08-49-24(1).mov
# Copied: IMG_E2550.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-38.jpg
# Copied: IMG_E2544.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-12.jpg
# Copied: IMG_9883.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_13-26-37.png
# Copied: IMG_2478.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_19-26-07.jpg
# Copied: IMG_2646.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-22_21-23-36.png
# Copied: IMG_2493.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_12-36-38.png
# Copied: IMG_2487.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_11-28-44(1).png
# Copied: IMG_2652.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-24_11-07-08.jpg
# Copied: IMG_2610.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_12-33-22(1).mov
# Copied: IMG_2612.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_12-48-05(1).mov
# Copied: IMG_2678.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_20-29-57.jpg
# Copied: BWLQ7466.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_22-02-45.jpg
# Copied: IMG_2650.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-23_14-16-56.jpg
# Copied: IMG_2491.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_12-04-06.jpg
# Copied: IMG_2308.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2023-01/2023-01-25_15-25-43.jpg
# Copied: _DSC3823.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-46-32(2).jpg
# Copied: QESB1794.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-12_13-35-47(1).jpg
# Copied: IMG_2687.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-29_07-56-18.png
# Copied: IMG_E2552.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-41.jpg
# Copied: IMG_E2546.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-34.jpg
# Copied: IMG_2532.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-27.jpg
# Copied: IMG_E2585.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-32.jpg
# Copied: IMG_2526.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-33-41.jpg
# Copied: IMG_9881.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-28-06.jpg
# Copied: IMG_9895.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-19-14.jpg
# Copied: IMG_9894.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_15-19-13(2).jpg
# Copied: IMG_9880.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_11-28-04.jpg
# Copied: SIOU0444.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_21-41-05.jpg
# Copied: IMG_2527.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-33-42.jpg
# Copied: IMG_E2584.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-31.jpg
# Copied: IMG_2533.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-30.jpg
# Copied: IMG_E2547.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-35.jpg
# Copied: IMG_E2553.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-42.jpg
# Copied: IMG_2686.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_22-34-30(1).png
# Copied: IMG_2309.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2023-01/2023-01-25_15-25-49(1).jpg
# Copied: IMG_2645.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-22_21-21-45.png
# Copied: IMG_2490.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_11-34-57.jpg
# Copied: IMG_2484.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_10-10-55(1).png
# Copied: IMG_2651.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-23_14-22-48.jpg
# Copied: IMG_3229.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-11/2022-11-25_10-10-31.jpg
# Copied: IMG_2607.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-58-53(1).mov
# Copied: IMG_E2667.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2024-01/2024-01-14_10-30-42.mov
# Copied: IMG_2636.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_16-39-06.jpg
# Copied: IMG_2660.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_03-34-22(1).mov
# Copied: IMG_2597.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-36-00.jpg
# Copied: IMG_2583.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-26.jpg
# Copied: IMG_2554.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-44(1).jpg
# Copied: IMG_2274 1.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-11_23-35-07.jpg
# Copied: IMG_2540.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-35-19.jpg
# Copied: IMG_2568.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-05(1).jpg
# Copied: IMG_2502.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-27(8).mov
# Copied: IMG_2516.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-33(11).mov
# Copied: IMG_9872.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-12(7).mov
# Copied: IMG_9866.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-10(2).mov
# Copied: IMG_9867.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-11(1).mov
# Copied: IMG_9873.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-27-40(1).mov
# Copied: IMG_2517.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-33(12).mov
# Copied: IMG_2569.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-06(1).jpg
# Copied: IMG_2503.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-27(9).mov
# Copied: IMG_2541.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-35-21.jpg
# Copied: IMG_2555.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-45(1).jpg
# Copied: IMG_2582.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-26(1).jpg
# Copied: IMG_2308 1.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2023-01/2023-01-25_15-25-43(1).jpg
# Copied: IMG_2596.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-35-58.jpg
# Copied: IMG_2637.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_17-23-19.png
# Copied: IMG_2661.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_03-34-52(1).mov
# Copied: GHXR1666.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-12_13-35-13.jpg
# Copied: IMG_2635.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_16-39-06(1).jpg
# Copied: IMG_2663.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_03-34-56(2).mov
# Copied: IMG_2609.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_15-30-05.jpg
# Copied: IMG_E2523.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-33-30(1).jpg
# Copied: IMG_2580.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-25.jpg
# Copied: IMG_2594.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-28-00.jpg
# Copied: IMG_2543.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-06(1).jpg
# Copied: IMG_2274 2.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-11_23-20-41(1).jpg
# Copied: IMG_2557.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-49(1).jpg
# Copied: IMG_2515.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-33(13).mov
# Copied: IMG_2501.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-27(10).mov
# Copied: IMG_9865.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-10(3).mov
# Copied: IMG_9871.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-12(8).mov
# Copied: BHAF6817.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_23-13-27.jpg
# Copied: BQAF9238.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_23-13-18.jpg
# Copied: IMG_9870.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-12(9).mov
# Copied: IMG_9864.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-09(2).mov
# Copied: IMG_2500.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-27(11).mov
# Copied: IMG_2514.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-33(14).mov
# Copied: IMG_2556.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-48(1).jpg
# Copied: IMG_2274 3.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-12/2022-12-11_23-35-41.jpg
# Copied: IMG_2595.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-28-00(1).jpg
# Copied: IMG_2581.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-25(1).jpg
# Copied: IMG_2634.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_14-28-16.png
# Copied: IMG_2662.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-27_03-34-56(3).mov
# Copied: IMG_2608.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_15-28-23.jpg
# Copied: IMG_2666.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_12-48-27(1).mov
# Copied: IMG_E2526.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-33-41(1).jpg
# Copied: IMG_2585.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-32(1).jpg
# Copied: IMG_E2532.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-27(1).jpg
# Copied: IMG_2591.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-27-12.jpg
# Copied: IMG_2510.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-33(8).mov
# Copied: IMG_2504.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-32(1).mov
# Copied: IMG_2546.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-34(1).jpg
# Copied: IMG_2552.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-41(1).jpg
# Copied: IMG_2538.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-35-05(2).mov
# Copied: IMG_9874.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-27-42(1).mov
# Copied: IMG_9875.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-27-44(1).mov
# Copied: IMG_9861.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-08(2).mov
# Copied: MJDY7207.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-10/2022-10-24_22-41-24.png
# Copied: IMG_2553.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-42(1).jpg
# Copied: IMG_2539.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_07-35-05(3).mov
# Copied: IMG_2547.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-35(1).jpg
# Copied: IMG_2505.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-33(9).mov
# Copied: IMG_2511.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-26(1).mov
# Copied: IMG_2590.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-27-11.jpg
# Copied: IMG_E2533.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-30(1).jpg
# Copied: IMG_2584.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-31(1).jpg
# Copied: IMG_E2527.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-33-42(1).jpg
# Copied: IMG_2619.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_11-30-09(1).png
# Copied: IMG_E2686.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_22-34-30.jpg
# Copied: IMG_2667.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_15-24-00(1).mov
# Copied: USSL8282.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_16-46-32(3).jpg
# Copied: NGCB2236.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_10-44-07(1).jpg
# Copied: IMG_2633.PNG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-21_10-24-09(1).png
# Copied: IMG_2498.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-27(12).mov
# Copied: IMG_2592.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-27-17.jpg
# Copied: IMG_E2531.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-16(1).jpg
# Copied: IMG_2586.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-33(1).jpg
# Copied: IMG_2507.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-33(10).mov
# Copied: IMG_2579.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-24.jpg
# Copied: IMG_2513.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-33(15).mov
# Copied: IMG_2551.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-39(1).jpg
# Copied: IMG_2545.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-32(1).jpg
# Copied: IMG_9877.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-27-52(2).mov
# Copied: IMG_9863.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-09(3).mov
# Copied: IMG_9888.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-18-59(8).mov
# Copied: IMG_9889.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_12-18-59(9).mov
# Copied: IMG_9862.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-00-08(3).mov
# Copied: IMG_9876.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-16_08-27-52(3).mov
# Copied: IMG_5798.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-11/2022-11-16_23-44-24.jpg
# Copied: IMG_2544.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-12(1).jpg
# Copied: IMG_2550.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-37-38(1).jpg
# Copied: RIDA1107 1.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-19_22-21-00(1).jpg
# Copied: IMG_2578.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-23(1).jpg
# Copied: IMG_2512.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-28-32(1).mov
# Copied: IMG_2506.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-33(11).mov
# Copied: IMG_2587.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-38-34(1).jpg
# Copied: IMG_3855.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2023-01/2023-01-17_12-18-27.jpg
# Copied: IMG_E2530.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_10-34-13(1).jpg
# Copied: IMG_2593.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-18_11-27-20.jpg
# Copied: IMG_E2487.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_11-28-44.jpg
# Copied: IMG_2499.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-17_13-15-27(13).mov
# Copied: IMG_2664.MOV → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-28_08-18-23(1).mov
# Copied: IMG_E2646.JPG → /Users/max/Pictures/Temp/iphone_photos_sorted/2022-09/2022-09-22_21-23-36.jpg

# %%
# if __name__ == "__main__":
#     source = input("Enter the path to the folder with unsorted images & videos: ").strip('"')
#     destination = input("Enter the path to the folder where sorted files will be saved: ").strip('"')
#     rename_option = input("Rename files by date & time taken? (y/n): ").strip().lower() == "y"

#     sort_media_by_date(source, destination, rename_by_date=rename_option)
#     print("\n✅ Sorting complete!")
